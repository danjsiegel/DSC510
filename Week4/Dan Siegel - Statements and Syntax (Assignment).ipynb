# %% [markdown]
# # Assignment 4 - Statements and Syntax
#
# ## Instructions
#
# In this assignment, we will continue working with the `avengers.csv`.  Copy over the `avengers_utf8.csv` you created in the last exercise to the working directory of this notebook. Open up `avengers_utf8.csv` and assign the lines to the `lines` variable.
#
# Follow the instructions for submitting a Jupyter Notebook assignment in the submitting assignments documentation.

# %% [markdown]
# ## 1. Convert lines to rows (5 points)
#
# Using a `for` statement, loop through the `lines` sequence and process each line into a row and add each processed row to the `rows` list.  For the purposes of this assignment, a row is a list of values that results from splitting each line by its delimiter (in this case a comma).  As an example, if the line input is `'1,2,apple,pear'`, then row output is `['1', '2', 'apple', 'pear']`.  Do not worry about converting values or cleaning up the input data at this point.
#
#
# <div class="alert alert-info">
# **Note**: In this data set, there is one record that contains extra commas.  This happens when commas are used to separate the fields and commas are used within the some of the data values.  In this case, the `url` field for this record is `"...Nicholas_Fury,_Jr._(Earth-616)#"` and the `name_alias` field is `"Nicholas Fury, Jr., Marcus Johnson"`. These values are both enclosed with quote characters, which means we should not treat the commas inside the quotes as field separators.  In later assignments, we will implement code to handle escaped commas, but for now we will ignore this field.
# </div>
#
# A normal row should contain 21 values.  Only add a row to the `rows` list if it contains 21 values.

# %%
avengers = open(r'C:\Users\Dan Siegel\Desktop\Classes\DSC510\Week3\avengers.csv','r')
lines = avengers.readlines()

rows = []
for line in lines:
    row=line.split(',')
    if len(row)==21:
        rows.append(row)

# %% [markdown]
# ## 2. Create a header with Python friendly names (5 points)
#
# In the second step, create a header with Python friendly names.  These names will be used to create a dictionary based record.  When creating the names, convert the original name to a new name using the following rules.  Assign the new header names to the `fieldnames` variable.
#
# 1. The new name should only use lower case letters, numbers, and underscores.
# 2. Replace spaces and slashes with underscores.
# 3. Strip trailing question marks and newlines.

# %%
fieldnames = []
for category in rows[0]:
    corr_category = category.lower()
    corr_category = corr_category.strip('\n').strip('?')
    corr_category = corr_category.replace('/','_')
    fieldnames.append(corr_category)
print(fieldnames)
# Out:
# ['url', 'name_alias', 'appearances', 'current', 'gender', 'probationary introl', 'full_reserve avengers intro', 'year', 'years since joining', 'honorary', 'death1', 'return1', 'death2', 'return2', 'death3', 'return3', 'death4', 'return4', 'death5', 'return5', 'notes']

# %% [markdown]
# ## 3. Create dict-based records (10 points)
#
# Using the `fieldnames` and `rows` variables from the last two parts, create `records` which contain Python dictionaries with the field names assigned to the appropriate values.

# %%
records = []
for row in rows[1:]:
    record={}
    for category in range(len(fieldnames)):
        record[fieldnames[category]]=row[category]
    records.append(record)

# %%
print (records[4]['name_alias'], records[4]['url'])
# Out:
# Thor Odinson http://marvel.wikia.com/Thor_Odinson_(Earth-616)

# %% [markdown]
# ## 4. Convert record values to appropriate types (10 points)
#
# Using a for loop, iterate through each record and convert each record value to the appropriate type.  Additionally, make sure to update the `years_since_joining` value to the current year. If the value does not need to be converted, strip any trailing spaces or newlines.

# %%
for rows in range(len(records)):
    for keys in fieldnames:
        if keys == 'appearances' or keys == 'year' or keys == 'years since joining':
            records[rows][keys]=int(records[rows][keys])
        else:
            records[rows][keys]=records[rows][keys].rstrip().lstrip().strip('\n')
            if keys == 'current' or keys.startswith('return') or keys.startswith('death'):
                if records[rows][keys]=='YES':
                    records[rows][keys]=True
                elif records[rows][keys]=='NO':
                    records[rows][keys]=False
                else:
                    records[rows][keys]=None
        if keys == 'years since joining':
            records[rows][keys]=(2018-(records[rows]['year']))

# %%
records
# Out:
# [{'appearances': 1269,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-63',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': '"Henry Jonathan ""Hank"" Pym"',
#   'notes': 'Merged with Ultron in Rage of Ultron Vol. 1. A funeral was held.',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Henry_Pym_(Earth-616)',
#   'year': 1963,
#   'years since joining': 55},
#  {'appearances': 1165,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-63',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Janet van Dyne',
#   'notes': 'Dies in Secret Invasion V1:I8. Actually was sent tto Microverse later recovered',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Janet_van_Dyne_(Earth-616)',
#   'year': 1963,
#   'years since joining': 55},
#  {'appearances': 3068,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-63',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': '"Anthony Edward ""Tony"" Stark"',
#   'notes': '"Death: ""Later while under the influence of Immortus Stark committed a number of horrible acts and was killed.\'  This set up young Tony. Franklin Richards later brought him back"',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Anthony_Stark_(Earth-616)',
#   'year': 1963,
#   'years since joining': 55},
#  {'appearances': 2089,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-63',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Robert Bruce Banner',
#   'notes': '"Dies in Ghosts of the Future arc. However ""he had actually used a hidden Pantheon base to survive"""',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Robert_Bruce_Banner_(Earth-616)',
#   'year': 1963,
#   'years since joining': 55},
#  {'appearances': 2402,
#   'current': True,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-63',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Thor Odinson',
#   'notes': "Dies in Fear Itself brought back because that's kind of the whole point. Second death in Time Runs Out has not yet returned",
#   'probationary introl': '',
#   'return1': True,
#   'return2': False,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Thor_Odinson_(Earth-616)',
#   'year': 1963,
#   'years since joining': 55},
#  {'appearances': 612,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-63',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Richard Milhouse Jones',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Richard_Jones_(Earth-616)',
#   'year': 1963,
#   'years since joining': 55},
#  {'appearances': 3458,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Mar-64',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Steven Rogers',
#   'notes': 'Dies at the end of Civil War. Later comes back.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Steven_Rogers_(Earth-616)',
#   'year': 1964,
#   'years since joining': 54},
#  {'appearances': 1456,
#   'current': True,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-65',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Clinton Francis Barton',
#   'notes': 'Dies in exploding Kree ship in Averngers Vol. 1  Issue 502. Brought back by Scarlet Witch. Dies again in House of M Vol 1 Issue 7. Is later brought back.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': True,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Clint_Barton_(Earth-616)',
#   'year': 1965,
#   'years since joining': 53},
#  {'appearances': 769,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-65',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Pietro Maximoff',
#   'notes': 'Dies in House of M Vol 1 Issue 7. Later comes back',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Pietro_Maximoff_(Earth-616)',
#   'year': 1965,
#   'years since joining': 53},
#  {'appearances': 1214,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-65',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Wanda Maximoff',
#   'notes': 'Dies in Uncanny_Avengers_Vol_1_14. Later comes back',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Wanda_Maximoff_(Earth-616)',
#   'year': 1965,
#   'years since joining': 53},
#  {'appearances': 115,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-65',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Jacques Duquesne',
#   'notes': 'Dies in Avengers_Vol_1_130. Brought back by the Chaos King',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Jacques_Duquesne_(Earth-616)',
#   'year': 1965,
#   'years since joining': 53},
#  {'appearances': 741,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Oct-67',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Heracles',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Hercules_(Earth-616)',
#   'year': 1967,
#   'years since joining': 51},
#  {'appearances': 780,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-68',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': "T'Challa",
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/T%27Challa_(Earth-616)',
#   'year': 1968,
#   'years since joining': 50},
#  {'appearances': 1036,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Nov-68',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Victor Shade (alias)',
#   'notes': 'Dies in Avengers_Vol_1_500. Is eventually rebuilt.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Vision_(Earth-616)',
#   'year': 1968,
#   'years since joining': 50},
#  {'appearances': 482,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Dec-69',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Dane Whitman',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Dane_Whitman',
#   'year': 1969,
#   'years since joining': 49},
#  {'appearances': 1112,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-73',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Natalia Alianovna Romanova',
#   'notes': 'Killed by The Hand. Later revived with The Stone of the Chaste.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Natalia_Romanova_(Earth-616)#',
#   'year': 1973,
#   'years since joining': 45},
#  {'appearances': 160,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Aug-73',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Brandt',
#   'notes': '"Dies in Silver_Surfer_Vol_3_3. Actually ""fragments of her essence were spread out all across the universe"""',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Mantis_(Earth-616)#',
#   'year': 1973,
#   'years since joining': 45},
#  {'appearances': 1886,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-76',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Henry P. McCoy',
#   'notes': 'NA',
#   'probationary introl': 'Jul-75',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Henry_McCoy_(Earth-616)#',
#   'year': 1976,
#   'years since joining': 42},
#  {'appearances': 332,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-76',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Heather Douglas',
#   'notes': '"Dies in Defenders_Vol_1_152. Later \'Obtained a new body.\' Dies in Annihilation:_Conquest_Vol_1_3. Comes back as ""As before"" also was once named Madame MacEvil because LOL. "',
#   'probationary introl': 'Jul-75',
#   'return1': True,
#   'return2': True,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Heather_Douglas_(Earth-616)#',
#   'year': 1976,
#   'years since joining': 42},
#  {'appearances': 557,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-76',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Patsy Walker',
#   'notes': 'Died during time on Defenders. Eventually ressurected by villian Grim Reaper along with Mockingbird to fight the Avengers.',
#   'probationary introl': 'Nov-75',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Patricia_Walker_(Earth-616)#',
#   'year': 1976,
#   'years since joining': 42},
#  {'appearances': 197,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Aug-75',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Matthew Liebowitz (birth name)',
#   'notes': 'Died during Return_to_the_Old_West. Resurrected by She Hulk in negotiation with Time Variance Authority. As a time traveller he died in 1938. Did not return',
#   'probationary introl': '',
#   'return1': True,
#   'return2': False,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Matthew_Hawk_(Earth-616)#',
#   'year': 1975,
#   'years since joining': 43},
#  {'appearances': 106,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-78',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Robert L. Frank Sr.',
#   'notes': 'Died in Vision_and_the_Scarlet_Witch_Vol_1_2. Did not return however he was eventually cloned but the clone was killed immediately.',
#   'probationary introl': 'Apr-77',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Robert_Frank_(Earth-616)#',
#   'year': 1978,
#   'years since joining': 40},
#  {'appearances': 692,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Mar-79',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Simon Williams',
#   'notes': 'Died in Avengers_Vol_1_9. Actually just in a death-like coma.',
#   'probationary introl': 'Apr-77',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Simon_Williams_(Earth-616)#',
#   'year': 1979,
#   'years since joining': 39},
#  {'appearances': 109,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-78',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Yondu Udonta',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Yondu_Udonta_(Earth-691)#',
#   'year': 1978,
#   'years since joining': 40},
#  {'appearances': 100,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-78',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': "Martinex T'Naga",
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Martinex_T%27Naga_(Earth-691)#',
#   'year': 1978,
#   'years since joining': 40},
#  {'appearances': 132,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-78',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Charlie-27',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Charlie-27_(Earth-691)#',
#   'year': 1978,
#   'years since joining': 40},
#  {'appearances': 108,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-78',
#   'gender': 'FEMALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Nicholette Gold',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Nicholette_Gold_(Earth-691)#',
#   'year': 1978,
#   'years since joining': 40},
#  {'appearances': 100,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-78',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Stakar',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Stakar_Ogord_(Earth-691)#',
#   'year': 1978,
#   'years since joining': 40},
#  {'appearances': 156,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-78',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Vance Astrovik',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Vance_Astro_(Earth-691)#',
#   'year': 1978,
#   'years since joining': 40},
#  {'appearances': 254,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': True,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-78',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Mar-Vell',
#   'notes': "The bad penny of the Marvel universe. First killed in Secret invasion. Revived during the Chaos war. Died again during aformentioned chaos war. Resurrected by the Kree Empire using theæM'Kraan Crystal. Third death during Avengers vs. X-Men. Has not return",
#   'probationary introl': '',
#   'return1': True,
#   'return2': True,
#   'return3': False,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Mar-Vell_(Earth-616)#',
#   'year': 1978,
#   'years since joining': 40},
#  {'appearances': 935,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Apr-79',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Carol Susan Jane Danvers',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Carol_Danvers_(Earth-616)#',
#   'year': 1979,
#   'years since joining': 39},
#  {'appearances': 576,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jun-79',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Samuel Thomas Wilson',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Samuel_Wilson_(Earth-616)#',
#   'year': 1979,
#   'years since joining': 39},
#  {'appearances': 141,
#   'current': True,
#   'death1': True,
#   'death2': True,
#   'death3': True,
#   'death4': True,
#   'death5': True,
#   'full_reserve avengers intro': 'Nov-88',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Jocasta',
#   'notes': '"From her article: Death1: ""Defeated Ultron and reversed the process leaving Jocasta a mindless husk."" Return 1: ""Ultron later revived Jocasta with a remote link activating the mental residue the Wasp left behind"" Death 2: ""Sacrificing herself to try to ki"',
#   'probationary introl': 'Jul-80',
#   'return1': True,
#   'return2': True,
#   'return3': True,
#   'return4': True,
#   'return5': True,
#   'url': 'http://marvel.wikia.com/Jocasta_(Earth-616)#',
#   'year': 1988,
#   'years since joining': 30},
#  {'appearances': 355,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-81',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Greer Grant Nelson',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Greer_Nelson_(Earth-616)#',
#   'year': 1981,
#   'years since joining': 37},
#  {'appearances': 933,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-82',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Jennifer Walters',
#   'notes': 'Dies during Red Hulk Saga. Returns when Lyra infiltrates Intelligenica and finds her in statis',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Jennifer_Walters_(Earth-616)#',
#   'year': 1982,
#   'years since joining': 36},
#  {'appearances': 348,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-83',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Monica Rambeau',
#   'notes': 'NA',
#   'probationary introl': 'Jan-83',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Monica_Rambeau_(Earth-616)#',
#   'year': 1983,
#   'years since joining': 35},
#  {'appearances': 206,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-84',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Eros',
#   'notes': 'NA',
#   'probationary introl': 'Jun-83',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Eros_(Earth-616)#',
#   'year': 1984,
#   'years since joining': 34},
#  {'appearances': 533,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-84',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'James R. Rhodes',
#   'notes': 'NA',
#   'probationary introl': 'May-84',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/James_Rhodes_(Earth-616)#',
#   'year': 1984,
#   'years since joining': 34},
#  {'appearances': 374,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-84',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Barbara Barton (nee Morse)',
#   'notes': 'Killed by Mephisto. After Secret Invasion it turns out she was actually being impersonated by a Skrull the whole time and was alive and well.',
#   'probationary introl': 'Jun-84',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Barbara_Morse_(Earth-616)#',
#   'year': 1984,
#   'years since joining': 34},
#  {'appearances': 2,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Nov-93',
#   'gender': 'FEMALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Moira Brandon',
#   'notes': 'Died in her second appearance earns honorary Avengers status doing so. Stays dead.',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Moira_Brandon_(Earth-616)#',
#   'year': 1993,
#   'years since joining': 25},
#  {'appearances': 2305,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jun-86',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Benjamin Jacob Grimm',
#   'notes': "Once killed during a battle with Doctor Doom.' Brought back by the FF when they literally went to Heaven to get him.",
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Benjamin_Grimm_(Earth-616)#',
#   'year': 1986,
#   'years since joining': 32},
#  {'appearances': 83,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-87',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Bonita Juarez',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Bonita_Juarez_(Earth-616)#',
#   'year': 1987,
#   'years since joining': 31},
#  {'appearances': 402,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jun-88',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Marc Spector',
#   'notes': 'NA but he he did die and return to get his powers prior to joining the Avengers.',
#   'probationary introl': 'Sep-87',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Marc_Spector_(Earth-616)#',
#   'year': 1988,
#   'years since joining': 30},
#  {'appearances': 352,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'John F. Walker',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/John_Walker_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 565,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Nov-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Jim Hammond (alias)',
#   'notes': '"Dies during New Invaders. Was ""was revived as a living weapon the Thinker intended to sell."" Prior to joining the avengers he had died like 2 times in the 40s. "',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Human_Torch_(Android)_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 112,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Apr-91',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Miguel Santos',
#   'notes': 'NA: Has not died since joing the Avengers but prior to joining he fought the West Coast avengers and seemingly died. Later turned up under control of a villain',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Miguel_Santos_(Earth-616)#',
#   'year': 1991,
#   'years since joining': 27},
#  {'appearances': 218,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Sep-92',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Julia Carpenter',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Julia_Carpenter_(Earth-616)#',
#   'year': 1992,
#   'years since joining': 26},
#  {'appearances': 149,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jun-92',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'X-51',
#   'notes': 'Died in Deathlok Vol 2 #5. JK that was actually just a Life Model Decoy',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/2ZP45-9-X-51_(Earth-616)#',
#   'year': 1992,
#   'years since joining': 26},
#  {'appearances': 168,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-93',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Christopher Powell',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Chris_Powell_(Earth-616)#',
#   'year': 1993,
#   'years since joining': 25},
#  {'appearances': 1561,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Dec-85',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Namor McKenzie',
#   'notes': 'Namor was presumed killed in the battle with Atlantean Barbarians. Had actually survived and turned up in the South Pacific',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Namor_McKenzie_(Earth-616)#',
#   'year': 1985,
#   'years since joining': 33},
#  {'appearances': 217,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '3-Feb',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Scott Edward Harris Lang',
#   'notes': "Died in Avengers:_Disassembled. Was brought back in the Young Avengers: Children's Crusade arc because time travel but take my word for it it was actually kind of well done.",
#   'probationary introl': 'Jan-87',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Scott_Lang_(Earth-616)#',
#   'year': 2003,
#   'years since joining': 15},
#  {'appearances': 158,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Apr-87',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Anthony Ludgate Druid',
#   'notes': 'Shot with a Breathing gun and corpse dumped in trash. Revived by the Grim Reaper. Helped Avengers defeat the Reaper so his spirit could remain at peace. Later completely revived by the Chaos King.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': True,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Anthony_Druid_(Earth-616)#',
#   'year': 1987,
#   'years since joining': 31},
#  {'appearances': 86,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Dec-87',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Marrina Smallwood',
#   'notes': 'Killed by Namor with the Ebony Blade. Returned when The Master put her in a statis tube. Death 2 was when Namor mercy killed her. Returned to life a second time by the Chaos King.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': True,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Marrina_Smallwood_(Earth-616)#',
#   'year': 1987,
#   'years since joining': 31},
#  {'appearances': 41,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-88',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Ravonna Lexus Renslayer',
#   'notes': 'Killed in Avengers_Vol_1_24. Revived by the Grandmaster. Died in Avengers:_Forever_Vol_1_3.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': False,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Ravonna_Renslayer_(Earth-6311)#',
#   'year': 1988,
#   'years since joining': 30},
#  {'appearances': 68,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Nov-88',
#   'gender': 'FEMALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Rita DeMara',
#   'notes': 'Killed by Iron Man when he was controlled by Immortus. Revived during Chaos war.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Rita_DeMara_(Earth-616)#',
#   'year': 1988,
#   'years since joining': 30},
#  {'appearances': 70,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jan-88',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Dennis Dunphy',
#   'notes': '"Died in Captain_America_348. Actually ""Dunphy miraculously survived the crash and lived with an Inuit tribe."" Second death when killed by Sharon Carter.  "',
#   'probationary introl': '',
#   'return1': True,
#   'return2': False,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Dennis_Dunphy_(Earth-616)#',
#   'year': 1988,
#   'years since joining': 30},
#  {'appearances': 61,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': '',
#   'notes': 'Killed by Neut who was working for Immortus. Reborn into a new body.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Gilgamesh_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 2125,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Reed Richards',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Reed_Richards_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 1761,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Susan Richards (nee Storm)',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Susan_Storm_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 293,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Oct-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Wendell Elvis Vaughn',
#   'notes': 'Killed by the Cosmic Assassin. Actually turned into a being composed of pure energy.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Wendell_Vaughn_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 36,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-89',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Ashley Crawford',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Ashley_Crawford_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 22,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-89',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': '',
#   'notes': 'Died in Great_Lakes_Avengers_Vol_1_1. Has not returned',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Dinah_Soar_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 31,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'DeMarr Davis',
#   'notes': 'Sacrificed self so that Mr. Immortal could stop the villain Maelstrom. Returned as the Angel of Death.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/DeMarr_Davis_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 34,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Val Ventura',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Val_Ventura_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 33,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-89',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Craig Hollis',
#   'notes': 'Christ; where to begin. His superpower is that he cannot die when he dies he immediately comes back. The Wikia inventories 24 deaths. These will be excluded from the analysis.',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Craig_Hollis_(Earth-616)#',
#   'year': 1989,
#   'years since joining': 29},
#  {'appearances': 4,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '5-Apr',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Gene Lorrene',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Gene_Lorrene_(Earth-616)#',
#   'year': 2005,
#   'years since joining': 13},
#  {'appearances': 47,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '5-May',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Dorreen Green',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Doreen_Green_(Earth-616)#',
#   'year': 2005,
#   'years since joining': 13},
#  {'appearances': 7,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '5-May',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': '',
#   'notes': 'Killed by Leather Boy',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Monkey_Joe_(Earth-616)#',
#   'year': 2005,
#   'years since joining': 13},
#  {'appearances': 3,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '5-May',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Doug Taggert',
#   'notes': 'Accidently killed by Zaran',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Doug_Taggert_(Earth-616)#',
#   'year': 2005,
#   'years since joining': 13},
#  {'appearances': 16,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '5-Jul',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': '',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Tippy-Toe_(Earth-616)#',
#   'year': 2005,
#   'years since joining': 13},
#  {'appearances': 575,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '7-Sep',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Wade Wilson',
#   'notes': "Died during incursion. It's not ever particulalry clear if he ever joined an Avengers team besides one issue so his inclusion here is specious at best.",
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Wade_Wilson_(Earth-616)#',
#   'year': 2007,
#   'years since joining': 11},
#  {'appearances': 58,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '9-Aug',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Greg Willis',
#   'notes': 'Died on Battleworld and came back prior to joining avengers',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Greg_Willis_(Earth-616)#',
#   'year': 2009,
#   'years since joining': 9},
#  {'appearances': 237,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-90',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Circe',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Sersi_(Earth-616)#',
#   'year': 1990,
#   'years since joining': 28},
#  {'appearances': 4333,
#   'current': True,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Apr-90',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Peter Benjamin Parker',
#   'notes': 'Since joining the New Avengers: First death Killed by Morlun. Ressurected in a brand new body. Died in Amazing Spider-Man #700. Eventually mainfested in his body that Octavious stole and then took over again.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': True,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Peter_Parker_(Earth-616)#',
#   'year': 1990,
#   'years since joining': 28},
#  {'appearances': 126,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-90',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Walter Newell',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Walter_Newell_(Earth-616)#',
#   'year': 1990,
#   'years since joining': 28},
#  {'appearances': 158,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '',
#   'gender': 'MALE',
#   'honorary': 'Probationary',
#   'name_alias': 'Elvin Haliday',
#   'notes': 'NA',
#   'probationary introl': 'Feb-91',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Elvin_Haliday_(Earth-616)#',
#   'year': 1900,
#   'years since joining': 118},
#  {'appearances': 355,
#   'current': False,
#   'death1': True,
#   'death2': False,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '',
#   'gender': 'MALE',
#   'honorary': 'Probationary',
#   'name_alias': 'William Baker',
#   'notes': 'Died in Identity_Disc_Vol_1_1. Later was revealed to be alive and working along with the Vulture.',
#   'probationary introl': 'Feb-91',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/William_Baker_(Earth-616)#',
#   'year': 1900,
#   'years since joining': 118},
#  {'appearances': 517,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jan-92',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Crystal Amaquelin Maximoff',
#   'notes': 'NA',
#   'probationary introl': 'Aug-91',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Crystalia_Amaquelin_(Earth-616)#',
#   'year': 1992,
#   'years since joining': 26},
#  {'appearances': 202,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jan-92',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Eric Kevin Masterson',
#   'notes': 'Became posessed died to purge self of corruption. Revived as undead Avenger minion of the Grim Reaper. Returned to the spirit world by the Scarlet Witch. Has since stayed dead.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': False,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Eric_Masterson_(Earth-616)#',
#   'year': 1992,
#   'years since joining': 26},
#  {'appearances': 31,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Dec-92',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Phillip Javert',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Philip_Javert_(Earth-921)#',
#   'year': 1992,
#   'years since joining': 26},
#  {'appearances': 28,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jun-93',
#   'gender': 'FEMALE',
#   'honorary': 'Honorary',
#   'name_alias': '',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Melissa_Darrow_(Earth-9201)#',
#   'year': 1993,
#   'years since joining': 25},
#  {'appearances': 50,
#   'current': False,
#   'death1': True,
#   'death2': True,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Jul-93',
#   'gender': 'FEMALE',
#   'honorary': 'Honorary',
#   'name_alias': '',
#   'notes': 'Reduced her to a pile of bones and organsby Vargas. Brought back by Chaos King. Died second time in Chaos_War:_Dead_Avengers_Vol_1_3',
#   'probationary introl': '',
#   'return1': True,
#   'return2': False,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Deathcry_(Earth-616)#',
#   'year': 1993,
#   'years since joining': 25},
#  {'appearances': 27,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Feb-96',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Anthony Edward Stark',
#   'notes': 'Merged with 616 Tony Stark',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Anthony_Stark_(Earth-96020)#',
#   'year': 1996,
#   'years since joining': 22},
#  {'appearances': 18,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'Apr-96',
#   'gender': 'FEMALE',
#   'honorary': 'Honorary',
#   'name_alias': '"""Giulietta Nefaria"""',
#   'notes': "Whitney killed was a clone possibly this incarnation of Masque'",
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Giuletta_Nefaria_(Masque)_(Earth-616)#',
#   'year': 1996,
#   'years since joining': 22},
#  {'appearances': 302,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': 'May-98',
# ...
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Ororo_Munroe_(Earth-616)#',
#   'year': 2012,
#   'years since joining': 6},
#  {'appearances': 1375,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '11-Nov',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Matt Murdock',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Matthew_Murdock_(Earth-616)#',
#   'year': 2011,
#   'years since joining': 7},
#  {'appearances': 746,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '12-Apr',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Flash Thompson',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Eugene_Thompson_(Earth-616)#',
#   'year': 2012,
#   'years since joining': 6},
#  {'appearances': 561,
#   'current': False,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Jan',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Otto Octavius',
#   'notes': 'Died in Superior_Spider-Man_Vol_1_30.',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Otto_Octavius_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 592,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '12-Dec',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Alex Summers',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Alexander_Summers_(Earth-616)#',
#   'year': 2012,
#   'years since joining': 6},
#  {'appearances': 679,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Feb',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Samuel Guthrie',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Samuel_Guthrie_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 491,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Feb',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Roberto da Costa',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Roberto_da_Costa_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 65,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Feb',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Eden Fesi',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Eden_Fesi_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 55,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Feb',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': '',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Captain_Universe_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 44,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Feb',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Izzy Kane',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Isabel_Kane_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 65,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Feb',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Marcus Milton',
#   'notes': 'Died in New_Avengers_Vol_3_32.',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Marcus_Milton_(Earth-13034)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 877,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Apr',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Anna Marie',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Rogue_(Anna_Marie)_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 176,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-May',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Shiro Yoshida',
#   'notes': "Died in Uncanny_Avengers_Vol_1_22. Returned when 'he was able to use his power to transform his body into a state of pure energy '",
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Shiro_Yoshida_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 24,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Oct',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': '',
#   'notes': 'Died in New_Avengers_Vol_3_32',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Ex_Nihilo_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 25,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Oct',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': '',
#   'notes': 'Died in New_Avengers_Vol_3_32',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Abyss_(Ex_Nihilo%27s)_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 35,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Oct',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Adam',
#   'notes': 'Died in New_Avengers_Vol_3_32',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Nightmask_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 44,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Oct',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Kevin Kale Connor',
#   'notes': 'Died in New_Avengers_Vol_3_32',
#   'probationary introl': '',
#   'return1': False,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Kevin_Connor_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 78,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '15-Feb',
#   'gender': 'MALE',
#   'honorary': 'Honorary',
#   'name_alias': 'Sam Alexander',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Sam_Alexander_(Earth-616)#',
#   'year': 2015,
#   'years since joining': 3},
#  {'appearances': 22,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Jul',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'America Chavez',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/America_Chavez_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 77,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Jul',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Loki Laufeyson',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Loki_Laufeyson_(Ikol)_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 115,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Sep',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'David Alleyne',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/David_Alleyne_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 69,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Apr',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Phillip Coulson',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Phillip_Coulson_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 173,
#   'current': False,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-May',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Tony Masters',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Tony_Masters_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 75,
#   'current': True,
#   'death1': True,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Sep',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Victor Mancha',
#   'notes': 'Died in Avengers_A.I._Vol_1_4. Returned in Avengers_A.I._Vol_1_9.',
#   'probationary introl': '',
#   'return1': True,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Victor_Mancha_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 12,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Sep',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Monica Chang',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Monica_Chang_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 14,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Sep',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': '',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Doombot_(Avenger)_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 13,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Nov',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Alexis',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Alexis_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 198,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '13-Nov',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Eric Brooks',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Eric_Brooks_(Earth-616)#',
#   'year': 2013,
#   'years since joining': 5},
#  {'appearances': 29,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '14-Jan',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Adam Brashear',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Adam_Brashear_(Earth-616)#',
#   'year': 2014,
#   'years since joining': 4},
#  {'appearances': 45,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '14-Jan',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Victor Alvarez',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Victor_Alvarez_(Earth-616)#',
#   'year': 2014,
#   'years since joining': 4},
#  {'appearances': 49,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '14-Jan',
#   'gender': 'FEMALE',
#   'honorary': 'Full',
#   'name_alias': 'Ava Ayala',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Ava_Ayala_(Earth-616)#',
#   'year': 2014,
#   'years since joining': 4},
#  {'appearances': 35,
#   'current': True,
#   'death1': False,
#   'death2': None,
#   'death3': None,
#   'death4': None,
#   'death5': None,
#   'full_reserve avengers intro': '15-Jan',
#   'gender': 'MALE',
#   'honorary': 'Full',
#   'name_alias': 'Kaluu',
#   'notes': 'NA',
#   'probationary introl': '',
#   'return1': None,
#   'return2': None,
#   'return3': None,
#   'return4': None,
#   'return5': None,
#   'url': 'http://marvel.wikia.com/Kaluu_(Earth-616)#',
#   'year': 2015,
#   'years since joining': 3}]

# %% [markdown]
# # 5. Filtering Records (10 points)
#
# Using a list comprehension, get the records for those Avengers with over 3000 appearances. Assign the output to the `over3000` variable.
#
# Use this to print the name and number of appearances for those Avengers.  When printing the names, some names may contain extra quotes.  Strip the `"` around the entire name and replace double quotes (`""`) with a single quote (`"`).

# %%
over3000=[]
for rows in range(len(records)):
    records[rows]['over3000'] = (records[rows]['appearances']>3000)
    if (records[rows]['appearances']>3000):
        over3000.append(rows)
print(over3000)
# Out:
# [2, 6, 73, 92]

# %%
for rows in range(len(records)):
    if records[rows]['over3000'] == True:
        appearances = records[rows]['appearances']
        name = records[rows]['name_alias']
        if name.startswith('"') and name.endswith('"'):
            name = name[1:-1]
        name = name.replace('""', '"')
        print("NAME:", name, "APPEARANCES:", appearances)
# Out:
# NAME: Anthony Edward "Tony" Stark APPEARANCES: 3068
# NAME: Steven Rogers APPEARANCES: 3458
# NAME: Peter Benjamin Parker APPEARANCES: 4333
# NAME: James "Logan" Howlett APPEARANCES: 3130

# %%
for individuals in over3000:
    appearances = records[individuals]['appearances']
    name = records[individuals]['name_alias']
    if name.startswith('"') and name.endswith('"'):
        name = name[1:-1]
        name = name.replace('""', '"')
    print("NAME:", name, "APPEARANCES:", appearances)
# Out:
# NAME: Anthony Edward "Tony" Stark APPEARANCES: 3068
# NAME: Steven Rogers APPEARANCES: 3458
# NAME: Peter Benjamin Parker APPEARANCES: 4333
# NAME: James "Logan" Howlett APPEARANCES: 3130
